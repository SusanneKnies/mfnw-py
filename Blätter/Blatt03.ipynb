# %% [markdown]
# # Blatt 3
#
# Auf Blatt 1 hattest du bereits gelernt, wie man Vektoren mit numpy erstellen kann. Ebenso kannst du auch Matrizen als numpy Objekt erstellen. Zuerst importieren wir hierfür wieder numpy:

# %%
import numpy as np

# %%
b = np.array([3, 4, 1])
A = np.array([[6, -1, 3], [7, -2, -2], [-5, 2, 4]])

# %% [markdown]
# ### Matrix-Vektor Multiplikation

# %%
A*b
# Out:
# array([[ 18,  -4,   3],
#        [ 21,  -8,  -2],
#        [-15,   8,   4]])

# %%
np.matmul(A, b)
# Out:
# array([17, 11, -3])

# %% [markdown]
# ### Lineare Gleichungssysteme
#
# Verwende np.linalg.solve

# %%
np.linalg.solve(A, b)
# Out:
# array([ 6. , 22.5, -3.5])

# %% [markdown]
# np.linalg.solve kann nur für eindeutig lösbare LGS verwendet werden:

# %%
B = np.array([[-6, 9, -12], [2, -3, 4], [4, -6, 8]])
c = np.array([-20, 7, 12])

# %%
np.linalg.solve(B, c)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 np.linalg.solve(B, c)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/linalg/_linalg.py:471, in solve(a, b)
#     468 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     469 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     470               over='ignore', divide='ignore', under='ignore'):
# --> 471     r = gufunc(a, b, signature=signature)
#     473 return wrap(r.astype(result_t, copy=False))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/linalg/_linalg.py:163, in _raise_linalgerror_singular(err, flag)
#     162 def _raise_linalgerror_singular(err, flag):
# --> 163     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
d = np.array([0, 0, 0])

# %%
np.linalg.solve(B, d)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 np.linalg.solve(B, d)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/linalg/_linalg.py:471, in solve(a, b)
#     468 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     469 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     470               over='ignore', divide='ignore', under='ignore'):
# --> 471     r = gufunc(a, b, signature=signature)
#     473 return wrap(r.astype(result_t, copy=False))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/linalg/_linalg.py:163, in _raise_linalgerror_singular(err, flag)
#     162 def _raise_linalgerror_singular(err, flag):
# --> 163     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
np.linalg.lstsq(B, c)
# Out:
# (array([ 0.44827586, -0.67241379,  0.89655172]),
#  array([], dtype=float64),
#  np.int32(1),
#  array([2.01494417e+01, 1.80672411e-15, 8.85640569e-32]))

# %%
np.linalg.lstsq(B, d)
# Out:
# (array([0., 0., 0.]),
#  array([], dtype=float64),
#  np.int32(1),
#  array([2.01494417e+01, 1.80672411e-15, 8.85640569e-32]))

# %% [markdown]
# Returns least square solution, residuals, rank of matrix, singular values of matrix
